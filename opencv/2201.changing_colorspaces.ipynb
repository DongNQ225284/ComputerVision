# %% [markdown]
# ## Chuyển đổi sang các Không gian màu khác nhau

# %% [markdown]
# **`cv2.cvtColor()`** Chuyển đổi một hình ảnh từ không gian màu này sang không gian màu khác. Hàm này chuyển đổi một hình ảnh đầu vào từ không gian màu này sang không gian màu khác. Trong trường hợp chuyển đổi sang không gian màu RGB, thứ tự các kênh phải được chỉ định rõ ràng (RGB hoặc BGR). Lưu ý rằng định dạng màu mặc định trong OpenCV thường được gọi là RGB nhưng thực tế là BGR (các byte bị đảo ngược). Vì vậy, byte đầu tiên trong một hình ảnh màu chuẩn (24 bit) sẽ là thành phần Xanh lam 8 bit, byte thứ hai sẽ là Xanh lục và byte thứ ba sẽ là Đỏ. Sau đó, byte thứ tư, thứ năm và thứ sáu sẽ là pixel thứ hai (Xanh lam, sau đó là Xanh lục, sau đó là Đỏ), v.v.
#
# ### Cú pháp hàm
# ``` python
# dst = cv2.cvtColor( src, code )
# ```
#
# `dst`: Ảnh đầu ra có cùng kích thước và độ sâu với `src` không.
#
# Hàm có **2 đối số bắt buộc**:
#
# 1. Ảnh đầu vào `src`: 8 bit không dấu, 16 bit không dấu ( CV_16UC... ), hoặc dấu phẩy động độ chính xác đơn.
#
# 2. Mã chuyển đổi không gian màu `code` (xem ColorConversionCodes).
#
# ### Tài liệu OpenCV
#
# 1. **`cv2.cvtColor`**: <a href="https://docs.opencv.org/3.4/d8/d01/group__imgproc__color__conversions.html#ga397ae87e1288a81d2363b61574eb8cab" target="_blank">Liên kết tài liệu</a>
#
# 2. **`ColorConversionCodes`**: <a href="https://docs.opencv.org/4.5.1/d8/d01/group__imgproc__color__conversions.html#ga4e0972be5de079fed4e3a10e24ef5ef0" target="_blank">Liên kết tài liệu</a>

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import Image

# %matplotlib inline

# %%
img = cv2.imread("image/coca-cola-logo.png", 1)
dst = cv2.cvtColor(img, cv2.COLOR_BGRA2GRAY)
print(dst.shape)

plt.imshow(dst, cmap="gray")
# Out:
# (700, 700)

# %% [markdown]
# ## Tách và hợp nhất các kênh màu

# %% [markdown]
# * **`cv2.split()`** Chia một mảng đa kênh thành nhiều mảng kênh đơn.
#
# * **`cv2.merge()`** Hợp nhất nhiều mảng để tạo thành một mảng đa kênh duy nhất. Tất cả các ma trận đầu vào phải có cùng kích thước.
#
# ### Tài liệu OpenCV
#
# <a href="https://docs.opencv.org/4.5.1/d2/de8/group__core__array.html#ga0547c7fed86152d7e9d0096029c8518a" target="_blank">Liên kết tài liệu</a>

# %%
# Split the image into the B,G,R components
img_NZ_bgr = cv2.imread("image/New_Zealand_Lake.jpg", cv2.IMREAD_COLOR)
b, g, r = cv2.split(img_NZ_bgr)

# Show the channels
plt.figure(figsize=[20, 5])

plt.subplot(141);plt.imshow(r, cmap="gray");plt.title("Red Channel")
plt.subplot(142);plt.imshow(g, cmap="gray");plt.title("Green Channel")
plt.subplot(143);plt.imshow(b, cmap="gray");plt.title("Blue Channel")

# Merge the individual channels into a BGR image
imgMerged = cv2.merge((b, g, r))
# Show the merged output
plt.subplot(144)
plt.imshow(imgMerged[:, :, ::-1])
plt.title("Merged Output")
# Out:
# Text(0.5, 1.0, 'Merged Output')
