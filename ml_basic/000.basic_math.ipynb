# %% [markdown]
# # Giải tích ma trận
#
# **1. Ký hiệu toán học**
#
# a) Số vô hướng
#
# \- Ký hiệu bằng chữ cái viết thường in nghiêng – ví dụ: $x$
#
# b) Vector
#
# \- Ký hiệu bằng chữ cái viết thường in đậm – ví dụ: $\mathbf{x}$
#
# c) Array (Vector theo hàng)
#
# \- Ký hiệu bằng chữ cái viết thường – ví dụ: x
#
# d) Ma trận
#
# \- Ký hiệu bằng chữ cái viết hoa in đậm – ví dụ: $\mathbf{X}$
#
# **2. Đạo hàm của hàm trả về một số vô hướng**
#
# **2.1** Cho hàm số $f(\mathbf{x}): \R ^n \to \R$
#
# Đạo hàm cấp 1 theo $\mathbf{x}$ được định nghĩa:
# $$
# \nabla f
# =
# \begin{bmatrix}
# \frac{\partial f(\mathbf{x})}{\partial x_1} \\
# ... \\
# \frac{\partial f(\mathbf{x})}{\partial x_n}
# \end{bmatrix}
# $$
#
# Hessian được định nghĩa như sau:
#
# $$
# \nabla^2 f
# =
# \begin{bmatrix}
# \frac{\partial^2 f(\mathbf{x})}{\partial x_1^2} & ... & \frac{\partial^2 f(\mathbf{x})}{\partial x_1x_n} \\
# ... & ... & ...\\
# \frac{\partial^2 f(\mathbf{x})}{\partial x_n^2} & ... & \frac{\partial^2 f(\mathbf{x})}{\partial x_nx_1}
# \end{bmatrix}
# $$
#
#
# **2.2** Cho hàm số $f(\mathbf{X}):\R^{n×d}\to\R$
#
# Đạo hàm cấp 1 theo $\mathbf{X}$ được định nghĩa:
#
# $$
# \nabla f
# =
# \begin{bmatrix}
# \frac{\partial f(\mathbf{x})}{\partial x_{11}} &
# ... & \
# \frac{\partial f(\mathbf{x})}{\partial x_{1d}} \\
# ... & ... & ...\\
# \frac{\partial f(\mathbf{x})}{\partial x_{n1}} &
# ... &
# \frac{\partial f(\mathbf{x})}{\partial x_{nd}}
# \end{bmatrix}
# $$
#
# **3  Đạo hàm của hàm trả về là một vector**
#
# **3.1** Cho hàm số $f(x):\R\to\R^n$
# $$
# f(x)
# =
# \begin{bmatrix}
# f_1(x) \\
# ... \\
# f_n(x)
# \end{bmatrix}
# $$
# Đạo hàm cấp 1 theo $x$ được định nghĩa:
#
# $$
# \nabla f
# =
# \begin{bmatrix}
# \frac{\partial f_1(x)}{\partial x} &
# ... &
# \frac{\partial f_n(x)}{\partial x}
# \end{bmatrix}
# $$
#
# **3.2** Cho hàm số fx:Rk→Rn
#
# Đạo hàm cấp 1 theo x** được định nghĩa:
#
# ∇fx=∂f1x∂x1…∂fnX∂x1………∂f1X∂xk…∂fnX∂xk=∇f1xT…∇fnxT
#
# **4 Tính chất quan trọng của đạo hàm**
#
# **4.1 Quy tắc tích (Product rule)**
#
# ∇fXTg(X)=∇fXgX+∇gXf(X)
#
# **4.2 Quy tắc chuỗi (Chain rule)**
#
# ∇XgfX=∇XfXT∇fgf
#
# **5 Đạo hàm của một số hàm thường gặp**
#
# **5.1** f:Rn→R,  fx=aTx
#
# fx=a1x1+…+anxn
#
# Khi đó, đạo hàm cấp 1:
#
# ∇fx =∂fx∂x1…∂fx∂xn=a1…an=a
#
# Hessian:
#
# ∇2fx=∂2fx∂x12…∂2fx∂x1xn………∂2fx∂xnx1…∂fx∂xn2=0…0………0…0=0∈Sn
#
# **5.2** f:Rn→Rm,  fx=Ax
#
# fx=a11…a1n………am1…amnx1…xn=a11x1+…+a1nxn…am1x1+…+amnxn=aiTx…amTx
#
# Khi đó, đạo hàm cấp 1:
#
# ∇fx=∇f1(x)…∇fn(x)=ai…am=AT
#
# **5.3** f:Rn→R,  fx=xTAx
#
# ∇fx=∇xTAx=∇xAx+∇Axx=Ax+ATx=A+ATx
#
# **5.4** f:Rn→R,  fx=Ax-b22=Ax-bT(Ax-b)
#
# ∇fx=2∇Ax-bAx-b=2AT(Ax-b)
#
# **5.5** f:Rn→R,  fx=aTxxTb
#
# ∇fx=∇aTxxTb
#
# =∇xTaxTb+∇xTbaTx
#
# =∇aTxbTx+∇bTxaTx
#
# =abTx+baTx=abT+baTx
#
# **5.6** f:Rn×d→R,   fX=trace(AX)
#
# bij=k=1naikxkj
#
# fX=traceAX=traceB=i=1dbii=i=1dj=1naijxji
#
# =b11+…+bdd=a11x11+…+a1nxn1+…+ad1x1d+…+adnxnd
#
# ∇fX=∂fX∂x11…∂fX∂x1d………∂fX∂xn1…∂fX∂xnd=a11…ad1………a1n…adn=AT
#
# **5.6** f:Rn×d→R,   fX=traceXA
#
# fX=traceAX=traceB=i=1nbii=i=1nj=1daijxji
#
# =b11+…+bnn=x11a11+…+x1dad1+…+xn1a1n+…+xndand
#
# ∇fX=∂fX∂x11…∂fX∂x1d………∂fX∂xn1…∂fX∂xnd=a11…ad1………a1n…adn=AT
#
# **6 Tổng hợp các công thức thường gặp**
#
#
# **
#
# **K - means clustering**
#
# X=x11…x1d………xN1…xNd=x1…xN,  y=y11…y1k………xN1…yNk=y1…yN,  M=m11…m1d………mk1…mkd=m1…mk
#
# **Loss function**
#
# LM,Y=i=1Nxi-yiM22=i=1Nxi-yiMxi-yiMT=i=1Nxi22+yiM22-2yiMxiT
#
# LM,Y=i=1Nxi22+i=1NyiM22-2 i=1NyiMxiT=XF2+YMF2-2traceYMXT
#
# ∂LM,Y∂M=∇MXF2+∇MYMF2-2∇MtraceYMXT=2YTYM-2YTX
#
# ∂LM,Y∂Y=∇YXF2+∇YYMF2-2∇YtraceXTYM=2YMMT-2XMT
#
# ∂LM,Y∂M=0∂LM,Y∂Y=0⇒&M=YTY+YTX&Y=XMTMMT+
#
#
#
#
#
#
#
# **Phụ lục. Ký tự thường gặp**
#
# **\bar**
#
# **\hat**
#
# **\nabla**
#
# **\parital**
#
# **\sigma**
#
# **\R**
#
# **\Rightarrow**
#
# **\Leftrightarrow**
